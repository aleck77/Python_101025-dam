# %% [markdown]
# ### 1. Сортировка чисел
#
# Напишите программу, которая запрашивает у пользователя три числа и выводит их в порядке возрастания, разделенные запятой.
#
# Пример вывода:
#
# - Введите первое число: 5
#
# - Введите второе число: 2
#
# - Введите третье число: 7
#
# ### Числа в порядке возрастания: 2, 5, 7

# %%
a = int(input('Введите первое число: ')) # 5
b = int(input('Введите второе число: ')) # 2
c = int(input('Введите третье число: '))  # 7
if a <= b and a <= c:
    n1 = a
    if b <= c:
        n2 = b
        n3 = c
    else:
        n2 = c
        n3 = b
elif b <= a and b <= c:
    n1 = b
    if a <= c:
        n2 = a
        n3 = c
    else:
        n2 = c
        n3 = a    
else:
    n1 = c
    if a <= b:
        n2 = a
        n3 = b
    else:
        n2 = b
        n3 = a
print('Числа в порядке возрастания: ', end='')
print(n1, n2, n3, sep=', ')

# %%
num1 = int(input("Введите первое число: "))
num2 = int(input("Введите второе число: "))
num3 = int(input("Введите третье число: "))
if num1 > num2:
    num1, num2 = num2, num1
if num1 > num3:
    num1, num3 = num3, num1
if num2 > num3:
    num2, num3 = num3, num2
print("Числа в порядке возрастания:", num1, num2, num3)

# %% [markdown]
# ### 2. Високосный год
#
# Напишите программу, которая запрашивает у пользователя год и проверяет, является ли он високосным.
#
# Год является високосным, если он делится на 4 без остатка, и в то же время не делится на 100 без остатка.
#
# При этом если год делятся на 400 без остатка, он тоже является високосным. Выведите соответствующее сообщение на экран с помощью функции print.
#
# Пример вывода:
#
# - Введите год: 2024
#
# Год является високосным.
#
# - Введите год: 2000
#
# Год является високосным.
#
# - Введите год: 1900
#
# Год не является високосным.

# %%
year = int(input('Введите год: '))
print('Год является високосным.' if year % 4 == 0 and year % 100 != 0 or year % 400 == 0 else 'Год не является високосным.')

# %%
import math
num = float(input("Введите вещественное число: "))
rounded_num = math.floor(num + 0.5) if num > 0 else math.ceil(num - 0.5)
print("Округленное значение:", rounded_num)

# %%
num = float(input("Введите вещественное число: "))
if num > 0:
    rounded_num = int(num + 0.5)
else:
    rounded_num = int(num - 0.5)
print("Округленное значение:", rounded_num)

# %%
import math

a = float(input("Введите длину первого катета: "))
b = float(input("Введите длину второго катета: "))
hypotenuse = math.sqrt(a**2 + b**2)
print("Длина гипотенузы:", hypotenuse)
