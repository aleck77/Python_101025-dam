# %%
print(1, 2, 3, 4, 5, sep="---")

# %%
string1 = "Первая строка с табуляцией"
string2 = "Вторая строка на новой строке"
print('\t'+string1+'\n'+string2)

# %%
print('Это файл "example.txt"')
print('Это файл \"example.txt\"')
print("Это файл \"example.txt\"")
print('''Это файл "example.txt"''')
