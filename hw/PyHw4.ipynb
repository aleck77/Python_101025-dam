# %% [markdown]
# ### 1. Логические операции
# Напишите программу, которая получит два логических значения от пользователя и выведет результат логических операций and, or, not для этих значений, а также сравнение на равенство и неравенство.
# - Для операции по используйте первое число. Продумайте в каком виде получать ввод от пользователя
# для логического значения.

# %%
bool1 = bool(int(input("Введите первое логическое значение (1 - Истина, 0 - Ложь): ")))
bool2 = bool(int(input("Введите второе логическое значение (1 - Истина, 0 - Ложь): ")))

and_result = bool1 and bool2
or_result = bool1 or bool2
not_result1 = not bool1
not_result2 = not bool2
equal_result = bool1 == bool2
not_equal_result = bool1 != bool2

print("AND: ", and_result)
print("OR: ", or_result)
print("NOT (для первого значения): ", not_result1)
print("NOT (для второго значения): ", not_result2)
print("Равно: ", equal_result)
print("Не равно: ", not_equal_result)

# %% [markdown]
# ### 2. Проверка условий
# Напишите программу, которая принимает на вход логические значения двух переменных (свет включён и окно открыто) и проверяет:
# - Оба ли условия выполнены.
# - Хотя бы одно из условий выполнено.

# %%
light_on = bool(int(input("Введите значение для свет включен (1 - Да, 0 - Нет): ")))
window_open = bool(int(input("Введите значение для скно открыто (1 - Да, 0 - Нет): ")))

and_result = light_on and window_open
or_result = light_on or window_open

print("Оба условия выполнены:", and_result)
print("Хотя бы одно из условий выполнено:", or_result)

# %% [markdown]
# ### 3. Стоимость мобильного тарифа
# Напишите программу для расчёта стоимости использования мобильного тарифа:
# - Базовая стоимость: 30 евро.
# - Каждый мегабайт интернета сверх 500 МБ стоит 0.2 евро.
#
# Программа должна запросить у пользователя количество использованных мегабайтов и вывести сколько всего он заплатил (базовый и переплата).

# %%
used_volume = float(input("Введите количество использованных мегабайтов: "))
base_cost = 30
free_megabytes = 500
over_price = 0.2

over_cost = (used_volume > free_megabytes) * (used_volume - free_megabytes) * over_price
print("Всего к оплате:", base_cost + over_cost, "евро")
