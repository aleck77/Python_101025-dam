# %% [markdown]
# # Summary 3

# %%
import b2f

print(b2f.float_to_binary_string(0.1))

# %%
print(b2f.binary_string_to_float("0.000110011001100110011001"))

# %% [markdown]
# ### Полезные материалы
# https://skillbox.ru/media/code/chisla-s-plavayushchey-tochkoy-chto-eto-takoe-i-kak-oni-rabotayut/

# %%
print(round(2.555,2))
print(round(3.555,2))
print(round(4.555,2))
print(round(5.555,2))

# %%
from decimal import Decimal

num1 = 2.555
num2 = 3.555
num3 = 4.555
num4 = 5.555
print(num1, ": ", Decimal(num1))
print(num2, ": ", Decimal(num2))
print(num3, ": ", Decimal(num3))
print(num4, ": ", Decimal(num4))

# %%
num = float(input("Введите вещественное число: "))

if num > 0:
    rounded_num = int(num + 0.5)
else:
    rounded_num = int(num - 0.5)

print("Округленное значение:", rounded_num)

# %%
a = float(input("Введите вещественное число: "))
result = int(a + 0.5) if a > 0 else int(a - 0.5)
print('Округленное значение:', result)

# %%
a = int(input('Введите длину первого катета:'))
b = int(input('Введите длину второго катета:'))
print('Длина гипотенузы:', (a**2+b**2)**0.5)
