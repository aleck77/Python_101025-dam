# %% [markdown]
# # Summary 6

# %%
str1 = 'sldfajkn arkgjno'

# %%
str1.isdigit()

# %%
str1 = '123.6'
str1.isdigit()
float(str1)

# %%
str1 = 'sldfajknarkgjno'
str1.isalpha()

# %%
str1 = 'sldfajkn arkgjno'
#print(str1.find('a'))
str1.find('a')

# %%
str1 = 'sldfajkn arkgjno'
print(str1.index('m'))

# %%
str1 = 'sldfajkn arkgjno'
print(str1.count('a'))

# %%
str1 = 'sldfajkn arkgjno'
print(str1.upper())

# %%
print(str1)

# %%
str1 = 'sldfajkn arkgjno'
str1 = str1.upper()
print(str1)

# %%
text = 'hello world!'

text = text.replace('hello', 'goodby')
print(text)

# %%
str1 = 'ijadbfvi1 sgfb 2 356 y7'
digits = '0123456789'

for digit in digits:
    str1 = str1.replace(digit,'')
print(str1)

# %%
str1 = 'ijadbfvi1, sgfb 2 356 y7'
print(str1.split())

# %%
numbers = input('вветите последовательность чисел:') #12, 34, 5, 6 
sm = 0
lst_numbers = numbers.split()
for num in lst_numbers:
    sm += int(num.strip())

print(sm)

# %%
num = ' 12,   '
print(num.strip())

# %%
numbers = input('вветите последовательность чисел:') #12, 34, 5, 6 
sm = 0
lst_numbers = numbers.split()
for num in lst_numbers:
    sm += int(num.strip('.,;: '))

print(sm)

# %%
words = ['Hello', 'my', 'friend']
print(' '.join(words))

# %% [markdown]
# ### Часто встречающиеся подзадачи на строки

# %% [markdown]
# 1. Поиск уникальных символов

# %%
s = 'programming'
result=''
for char in s:
    if char not in result:
        result += char
print(result)

# %% [markdown]
# 2. Является ли слово аннограммой

# %%
word1 = 'bannab'

print(word1 == word1[::-1])

# %% [markdown]
# 3. Заменить все встречаемые символы подстроки в строке

# %%
# способ 1. Цикл по всем элементам (Заменяем все цифры на *)

# %%
text = 'ijdnij 1 4r53 8'
result=''
for ch in text:
    if '0'<=ch<='9':
        result += '*'
    else:
        result += ch
print(result)

# %%
# способ 2. методы
text = 'ijdnij 1 4r53 8'
digits = '0123456789'
for dig in digits:
    text = text.replace(dig,'*')
print(text)

# %% [markdown]
# ### Разбор ДЗ

# %% [markdown]
# ***Звёздочки вместо чисел***
# Напишите программу, которая заменяет все цифры в строке на звёздочки *.
# text = "My number is 123-456-789"
# Пример вывода:
# Строка: My number is 123-456-789
# Результат: My number is `***-***-***`

# %%
text = "My number is 123-456-789"
print("Строка:", text)
result = text
for char in text:
    if char.isdigit():
        result = result.replace(char, "*")
print("Результат:", result)

# %% [markdown]
# ***Увеличение чисел***
# Напишите программу, которая делает все целые числа в строке в 10 раз больше.
# text = "I have 5 apples and 10 oranges, price is 0.5 each. Card number is ....3672."
#
# Пример вывода:
# I have 50 apples and 100 oranges, price is 5.0 each. Card number is ....3672.

# %%
text = "I have 5 apples and 10 oranges, price is 5.0 each. Card number is ....3672."
words = text.split() #['I', 'have', '5',... , '....3672.']


for i in range(len(words)):
    if words[i].isdecimal():
        words[i] = str(int(words[i]) * 10)


new_text = " ".join(words)
print(new_text)

# %%
text = "I have 5 apples and 10 oranges, price is 5.0 each. Card number is ....3672."

result = "" #Сюда итог собираем
num_str = "" #Сюда накапливаем текущее число

for char in text + " ":
    if char.isdigit() or char == '.':
        num_str += char
    else:
        if num_str: #5.0
            dots_count = num_str.count('.')
            if dots_count <= 1 and len(num_str) > dots_count:
                if '.' in num_str:
                    # Вещественное число
                    integer_part, fractional_part = num_str.split('.')
                    new_number = str(float(num_str) * 10)
                    if new_number.endswith('.0'):
                        result += new_number
                    # else:
                    #     result += new_number.rstrip('0').rstrip('.') if '.' in new_number else new_number
                else:
                    # Целое число
                    result += str(int(num_str) * 10)
            else:
                result += num_str
            num_str = ""
        
        result += char

result = result[:-1]
print(result)

# %%
'....3672.'.split(".")

# %%
text = "I have 5 apples and 10 oranges, price is 0.5 each. Card number is ....3672.".split()
result = ''

for word in text:
    if word.isdigit():
        word = str(int(word)*10)
    if "." in word:
        parts = word.split(".")
        if len(parts) == 2 and parts[0].isdigit() and parts[1].isdigit():
            word = str(float(word)*10)
    result += word + ' '
print(result)

# %% [markdown]
# ***Сумма положительных чисел***
# Напишите программу, которая обрабатывает список float чисел, вычисляет сумму положительных чисел.
# Результат необходимо вывести в формате денежной суммы (до 2 символов после запятой), добавляя символ валюты "$" вначале и разделяя тысячи запятой.
#
# Пример вывода:
# numbers = [1245.4435, -302.1403, 87459.99, -520.8265, 1450.001]
# Пример вывода:
# Сумма положительных чисел: $90,155.43

# %%
numbers = [1245.4435, -302.1403, 87459.99, -520.8265, 1450.001]

# Инициализируем переменную для хранения суммы положительных чисел
positive_sum = 0

# Фильтруем положительные числа и суммируем их
for num in numbers:
    if num > 0:
        positive_sum += num
        
# Форматируем результат в денежном формате
formatted_sum = "${:,.2f}".format(positive_sum)

print(f"Сумма положительных чисел: {formatted_sum}")

# %%
print(f"Сумма положительных чисел: ${positive_sum:,.2f}")

# %% [markdown]
# ***Сумма положительных чисел***
# Напишите программу, которая принимает список строк в формате "name age balance" и выводит информацию о каждом человеке с отформатированными данными: имя — 10 символов, возраст — 3 символа, баланс — 10 символов с двумя знаками после запятой. Используйте заранее подготовленный список строк.

# %%
# Данные:
# data_list = [
#     "John 23 12345.678",
#     "Alice 30 200.50",
#     "Bob 35 15000.3",
#     "Charlie 40 500.75"
# ]

# Пример вывода:
# Имя: John       | Возраст:  23 | Баланс:  12345.68  
# Имя: Alice      | Возраст:  30 | Баланс:    200.50  
# Имя: Bob        | Возраст:  35 | Баланс:  15000.30  
# Имя: Charlie    | Возраст:  40 | Баланс:    500.75

# %%
data_list = [
    "John 23 12345.678",
    "Alice 30 200.50",
    "Bob 35 15000.3",
    "Charlie 40 500.75"
]

for person in data_list:
    name, age, balance = person.split()
    age = int(age)
    balance = float(balance)
    print("Имя: {:<10} | Возраст: {:>3} | Баланс: {:>10.2f}".format(name, age, balance))

# %% [markdown]
# ***Звёздочки вместо чисел***
# Напишите программу, которая принимает список строк в формате "name age balance" и выводит информацию о каждом человеке с отформатированными данными: имя — 10 символов, возраст — 3 символа, баланс — 10 символов с двумя знаками после запятой. Используйте заранее подготовленный список строк.
# Пример вывода:
# data_list = [
#     "John 23 12345.678",
#     "Alice 30 200.50",
#     "Bob 35 15000.3",
#     "Charlie 40 500.75"
# ]

# %%
# Пример вывода:
# Имя: John       | Возраст:  23 | Баланс:  12345.68  
# Имя: Alice      | Возраст:  30 | Баланс:    200.50  
# Имя: Bob        | Возраст:  35 | Баланс:  15000.30  
# Имя: Charlie    | Возраст:  40 | Баланс:    500.75

# %%
data_list = [
    "John 23 12345.678",
    "Alice 30 200.50",
    "Bob 35 15000.3",
    "Charlie 40 500.75"
]

for person in data_list:
    name, age, balance = person.split()
    age = int(age)
    balance = float(balance)
    print("Имя: {:<10} | Возраст: {:>3} | Баланс: {:>10.2f}".format(name, age, balance))
