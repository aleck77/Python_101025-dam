# %%
import sys
print(f"Python версия: {sys.version}")
print(f"Путь к Python: {sys.executable}")
print(f"Платформа: {sys.platform}")
# Out:
# Python версия: 3.12.3 (main, Aug 14 2025, 17:47:21) [GCC 13.3.0]
# Путь к Python: /home/ich/projects/python/.venv/bin/python
# Платформа: linux
