# %% [markdown]
# # Практикум 3

# %% [markdown]
# 1. ***Округление вверх и вниз***
#
# Напишите программу, которая:
# принимает число с плавающей запятой
# выводит результат округления вверх и вниз
#
# Пример вывода:
#
# Введите число: 4.3
#
# Округление вверх: 5
#
# Округление вниз: 4

# %%
import math
a = float(input("Введите вещественное число: "))
result = math.floor(a + 0.5) if a > 0 else math.ceil(a - 0.5)
print('Округленное значение:', result)

# %% [markdown]
# 2. Найти сумму числового ряда от 1 до введенного числа n

# %%
n = int(input())
i = 1
s = 0
while n >= i:
    s+=i
    i+=1
print(s)

# %% [markdown]
# Найти сумму четных чисел ряда

# %%
n = int(input())
i = 0
s = 0
while n >= i:
    s+=i
    i+=2
print(s)

# %%
n = int(input())
i = 0
s = 0
while n >= i:
    if i % 2 == 0:
        s+=i
    i+=2
print(s)

# %% [markdown]
# Найти сумму чисел числового ряда, которые делятся на 3 и 11

# %%
n = int(input())
i = 0
s = 0
while n >= i:
    if i % 3 == 0 and i % 11 ==0:
        s+=i
    i+=1
print(s)

# %% [markdown]
# 3. ***Счётчик факториала***
#
# Напишите программу, которая рассчитывает факториал заданного числа
# (произведение всех целых чисел от 1 до самого числа) двумя способами.
# Выведите оба результата и сравните равны ли они.
#
# Пример вывода:
#
# Введите число: 5
#
# Факториал числа 5 первым способом: 120
#
# Факториал числа 5 вторым способом: 120
#
# Результаты равны? True

# %%
import math
n = int(input())
f = math.factorial(n)
print(str(n)+'!=', f)

i = 1
p = 1
while n >= i:
    p *= i
    i += 1
print(p==f)

# %%
n = int(input())
i = 1
p = 1
while n >= i:
    p *= i
    i += 1
print(p==f)

# %% [markdown]
# Для заданного целого числа N подсчитать количество четных чисел, меньше или равных N.

# %%
n = int(input())
i = 1
cnt = 0
while i <= n:
    if i % 2 == 0:
        cnt += 1
    i += 1
print(cnt)

# %% [markdown]
# По данному натуральному числу N найдите наибольшую целую степень двойки, не превосходящую N. Выведите показатель степени и саму степень.

# %%
p = 0
n = int(input())
while 2**p <= n:
    p += 1
print(p-1, 2**(p-1))

# %%
p = 0
n = int(input())
while True:
    if 2**p > n:
        break
    p += 1
print(p-1, 2**(p-1))

# %%
p = 0
n = int(input())
while n//2 > 0:
    p += 1
    n //= 2
print(p, 2**(p))

# %% [markdown]
# Дано целое число, не меньшее 2. Выведите его наименьший натуральный делитель, отличный от 1.

# %%
p = 2 # 2 ..... n
n = int(input())
while True:
    if n % p ==0:
        print('НОД', p)
        break
    p += 1

# %% [markdown]
# Определите сумму всех элементов последовательности, завершающейся числом 0. Числа, следующие за первым нулем, учитывать не нужно. Числа считываем с клавиатуры с помощью input()

# %%
s = 0
while True:
    num = int(input())
    if num == 0:
        break
    s += num
print(s)

# %%
s = 0
num = int(input())
while num != 0:
    s += num
    num = int(input())
print(s)

# %% [markdown]
# 4. ***Симулятор кассы***
#
# Напишите программу, которая принимает от пользователя цены товаров. Пользователь вводит цены по одному (ввод завершается при вводе нуля).
#
# Программа должна:
#
# * Рассчитать и вывести общую сумму покупки, округленную до целого числа.
# * Определить, какую сумму покупатель должен заплатить, если у него есть только купюры номиналом 100 евро.
# * Рассчитать и вывести сдачу, которую нужно дать покупателю.

# %%
total_sum = 0
while True:
    price = float(input('Введите цену товара: (Для завершения ввода нажмите 0)'))
    if price == 0:
        print('Округленная сумма:',round(total_sum))
        break
    total_sum += price
cnt100 = total_sum//100 if total_sum%100 == 0  else  total_sum//100 + 1
print('Дай', int(cnt100),'по 100 евро')
print('Сдача:', cnt100*100 - total_sum)

# %% [markdown]
# 5. ***Учет доходов и расходов***
#
# Напишите программу, которая принимает на вход положительные и отрицательные значения и останавливается получив ноль. Программа должна рассчитать сумму доходов (положительные) и расходов (отрицательные), а также итоговый баланс.
#
# Пример вывода:
#
# Введите доход, расход или '0' для получения итога: 15000
#
# Введите доход, расход или '0' для получения итога: -5000
#
# Введите доход, расход или '0' для получения итога: -3000
#
# Введите доход, расход или '0' для получения итога: 0
#
# Доходы: 15000
#
# Расходы: 8000
#
# Итоговый баланс: 7000

# %%
income = 0
cost = 0
while True:
    value = int(input('Введите число: (Для выхода используем 0)'))
    if value == 0:
        print('Доходы:',income)
        print('Доходы:',cost)
        break
    if value > 0:
        income += value
    if value < 0:
        cost += value
balans = income + cost
print('Итоговый баланс: ', balans)

# %% [markdown]
# Определите среднее значение всех элементов последовательности, завершающейся числом 0. Среднее значение - сумма всех элементов, поделенная на их количество.

# %%
sum = 0
cnt = 0
while True:
    num=int(input("Введите число"))
    if num == 0:
        break
    sum += num
    cnt += 1
print( "Среднее значение", round(sum/cnt, 2))

# %% [markdown]
# Последовательность состоит из натуральных чисел и завершается числом 0. Определите значение наибольшего элемента последовательности.

# %%
max = 0
while True:
    num = int(input("Введите число"))
    if num == 0:
        break
    if max < num:
        max = num
print(max)

# %%
mn = 10**6
flag = True
n = int(input())
while n != 0:
    if n < mn:
        mn = n
    n = int(input())
    flag=False
print('-'*10)
if flag:
    print('нет чисел')
else:
    print(mn)

# %%
mx = -10**6
flag = True
n = int(input())
while n != 0:
    if n > mx:
        mx = n
    n = int(input())
    flag=False
print('-'*10)
if flag:
    print('нет чисел')
else:
    print(mx)

# %% [markdown]
# Последовательность состоит из натуральных чисел и завершается числом 0. Определите индекс наибольшего элемента последовательности. Нумерация элементов начинается с нуля.

# %%
max = 0
cnt = 0
cnt_max = 0
while True:
    num = int(input("Введите число"))
    if num == 0:
        break
    if max < num:
        max = num
        cnt_max = cnt
    cnt += 1
    print(cnt_max)

# %%
max_n = 0
cnt = 0
while True:
    num = int(input("Введите число больше 1: (Для завершения ввода нажмите 0)"))
    cnt += 1
    if num == 0:
        break
    if num > max_n:
        max_n = num
        index_max = cnt
print('Xmax = ', max_n, "Index(Xmax) = ",index_max)

# %%
maximum = -10**10
count = 0
count_max = None
while True:
    n = int(input('Введите натуральные чисело и цикл завершается числом 0:  '))
    if n == 0:
        break
    if n > maximum:
        maximum = n
        count_max = count 
    count += 1
print('значение наибольшего элемента', count_max)

# %% [markdown]
# 6. Вычислите n-е число ряда Фибоначчи с помощью цикла while. Что такое числа Фибоначчи?

# %%
# 0, 1, 1, 2, 3, 5, 8, 13, 21....
num = int(input('Введите n-е число ряда Фибоначи'))
ind = 1
a, b = 0, 1
while ind < num:
    a, b = b, a + b
    ind += 1
print('n-е число ряда Фибоначи', a)

# %% [markdown]
# 7. ***Число Армстронга***
#
# Напишите программу, которая запрашивает у пользователя целое число и проверяет, является ли оно числом Армстронга. Число Армстронга — это число, которое равно сумме своих цифр, которые были возведены в степень, равную количеству цифр в числе.
# Например 153 = 1^3 + 5^3 + 3^3 = 1 + 125 + 27
#
# Пример вывода:
#
# Введите число: 153
#
# Число 153 является числом Армстронга.
#
# Введите число: 123
#
# Число 123 не является числом Армстронга.

# %%
n = int(input('ВВедите чисело  '))
t = n
count = 0
s = 0
while n > 0:
    n = n//10 #n//=10
    count+=1
n = t
while n > 0:
    s += (n%10)**count
    n = n//10 #n//=10

if t == s:
    print('A')
else:
    print('нет')

# %%
temp = n = int(input('Введите число :'))
cnt = 0
summa = 0
while temp > 0:
    cnt += 1
    temp = temp//10
temp = n
while temp > 0:
    dig = temp%10
    summa += dig**cnt
    temp = temp//10
if n == summa:
    print('Число ',summa, ' является числом  Армстронга')
else:
    print('Число ',summa, ' не является числом  Армстронга')

# %% [markdown]
# 8. ***Угадай за 5 попыток***
#
# Напишите программу, которая генерирует случайное число от 1 до 10 и просит пользователя угадать его за 5 попыток. Если пользователь не угадывает за 5 попыток, программа выводит загаданное число.
#
# Пример вывода:
#
# Попробуйте угадать число от 1 до 10: 10
#
# Неверно! У вас осталось 4 попытки.
#
# Попробуйте угадать число от 1 до 50: 3
#
# Неверно! У вас осталось 3 попытки.
#
# Попробуйте угадать число от 1 до 50: 7
#
# Поздравляем! Вы угадали число.

# %%
import random
secret_num = random.randint(1, 10)
attemts = 5
while attemts > 0:
    guess = int(input('Попробуйте угадать число от 1 до 10:'))
    if guess == secret_num:
        print('Поздравляем! Вы угадали число.')
        break
    else:
        attemts -= 1
        print('Неверно! У вас осталось', attemts, 'попытки.')
else:
    print('Вы не угадали, задуманное число:',secret_num)

# %%
import random

secret_num = random.randint(1,10)
attempts = 5
while attempts > 0:
    guess = int(input('Попробуйте угадать число от 1 до 10:'))
    if guess == secret_num:
        print('Поздравляем! Вы угадали число.')
        break
    else:
        attempts -= 1
        if attempts > 0:
            print('Неверно! У вас осталось', attempts ,'попытки.')
        else:
            print('Вы не угадали')
else:
    print(secret_num)

# %% [markdown]
# 9. ***Определение простого числа***
#
# Напишите программу, которая запрашивать число у пользователя и определяет, является ли заданное число простым.
#
# Число является простым, если оно:
# Больше 1.
# Имеет только два делителя: единицу и само себя.
#
# Пример вывода:
# Введите число: 29
# Число 29 является простым.
# Введите число: 15
# Число 15 не является простым.

# %% [markdown]
# 10. ***Упорядоченность цифр***
#
# Напишите программу, которая получает натуральное число и определяет, являются ли его цифры упорядоченными по возрастанию.
#
# Пример вывода:
# Введите число: 1347
# Цифры упорядочены по возрастанию.
# Введите число: 1523
# Цифры не упорядочены по возрастанию.
